# %% [markdown]
# # Reporte 8 — Promedio Académico por Semestre
#
# Mismo enfoque que el reporte 7 pero agrupando por `semestre` (índice 2) en lugar de carrera.

# %% [markdown]
# ## Inicialización de variables
#
# `prom_semestre` sigue la misma estructura: `[semestre, suma_promedios, cantidad]`.

# %%
import csv

# Columnas: id(0) carrera(1) semestre(2) jornada(3) trabaja(4) promedio_actual(5)
INDICE_SEMESTRE = 2
INDICE_PROMEDIO = 5

# [semestre, suma_promedios, cantidad_estudiantes]
prom_semestre = []

# %% [markdown]
# ## Lectura del CSV
#
# El semestre se convierte a `int` para comparaciones exactas. La lógica de agrupación es idéntica a la del reporte 7.

# %%
with open("../encuesta_ingenieria_10000_respuestas.csv", "r", encoding="utf-8") as estudiante:
    encuesta = csv.reader(estudiante)
    next(encuesta)

    for fila in encuesta:
        semestre = int(fila[INDICE_SEMESTRE].strip())
        promedio = float(fila[INDICE_PROMEDIO].strip())
        encontrado = False

        for s in prom_semestre:
            if s[0] == semestre:
                s[1] += promedio
                s[2] += 1
                encontrado = True
                break

        if not encontrado:
            prom_semestre.append([semestre, promedio, 1])

# %% [markdown]
# ## Resultado
#
# Se ordena por número de semestre antes de imprimir.

# %%
prom_semestre.sort(key=lambda s: s[0])

for s in prom_semestre:
    prom = s[1] / s[2]
    print(f"Semestre {s[0]}: {round(prom, 2)}")

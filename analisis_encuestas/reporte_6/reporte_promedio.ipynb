# %% [markdown]
# # Reporte 6 — Promedio General Académico
#
# Se lee la columna `promedio_actual` (índice 5) del CSV, se suman todos los valores y se divide entre el total de encuestados.

# %% [markdown]
# ## Inicialización de variables
#
# `suma` acumula los promedios de cada fila. `total` cuenta los registros para calcular la media.

# %%
import csv

# Columnas: id(0) carrera(1) semestre(2) jornada(3) trabaja(4) promedio_actual(5)
INDICE_PROMEDIO = 5

suma  = 0
total = 0

# %% [markdown]
# ## Lectura del CSV
#
# Por cada fila se convierte `promedio_actual` a `float` y se acumula en `suma`.

# %%
with open("../encuesta_ingenieria_10000_respuestas.csv", "r", encoding="utf-8") as estudiante:
    encuesta = csv.reader(estudiante)
    next(encuesta)

    for fila in encuesta:
        suma  += float(fila[INDICE_PROMEDIO].strip())
        total += 1

# %% [markdown]
# ## Resultado

# %%
promedio_general = suma / total

print(f"Total de encuestados : {total}")
print(f"Promedio general     : {round(promedio_general, 2)}")
